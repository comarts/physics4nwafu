# %% [markdown]
# # 第1章 物质的基本性质
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第2章 流体力学基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 液体的表面现象
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 电场和磁场
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 热力学基础

# %% [markdown]
# ## 热力学的基本概念

# %% [markdown]
# ## 热力学第一定律

# %% [markdown]
# ## 热力学第一定律在理想气体中的应用

# %% [markdown]
# ## 循环过程

# %% [markdown]
# ## 热力学第二定律

# %% [markdown]
# ## 热力学第二定律的统计意义

# %% [markdown]
# ## 熵

# %% [markdown]
# ## 耗散结构

# %% [markdown]
# ## 熵与自然观

# %% [markdown]
# ## 思考题

# %% [markdown]
# ## 习题
