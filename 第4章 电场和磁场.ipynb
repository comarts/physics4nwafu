# %% [markdown]
# # 第1章 物质的基本性质
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第2章 流体力学基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 液体的表面现象
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 电场和磁场

# %% [markdown]
# ## 电场和磁场的描述

# %% [markdown]
# ## 高斯定理

# %% [markdown]
# ## 恒定电磁场的环路定理

# %% [markdown]
# ## 电介质和磁介质

# %% [markdown]
# ## 带点粒子在电磁场中的运动

# %% [markdown]
# ## 生物电磁学简介

# %% [markdown]
# ## 思考题

# %% [markdown]
# ## 习题
