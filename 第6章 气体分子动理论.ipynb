# %% [markdown]
# # 第1章 物质的基本性质
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 第2章 流体力学基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 液体的表面现象
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 电场和磁场
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 热力学基础
#
# 🔖为保持章节序号与课本一致，此处为章标题占位符，具体内容请参阅对应章的 ipynb 文件。
#
# # 气体分子动理论

# %% [markdown]
# ## 分子动理论的基本概念

# %% [markdown]
# ## 理想气体的压强和温度

# %% [markdown]
# ## 能量均分定理

# %% [markdown]
# ## 麦克斯韦速率分布统计规律

# %% [markdown]
# ## 玻耳兹曼分布律

# %% [markdown]
# ## 气体分子的平均自由程

# %% [markdown]
# ## 热扩散现象

# %% [markdown]
# ## 思考题

# %% [markdown]
# ## 习题
